# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
taxi = pd.read_csv('/home/jupyter-l.fedoseeva-12/Lesson_4/taxi_peru (1).csv', sep=';')

# %%
taxi['start_at'] = pd.to_datetime(taxi['start_at'])
taxi['end_at'] = pd.to_datetime(taxi['end_at'])
taxi['arrived_at'] = pd.to_datetime(taxi['arrived_at'])

# %%
new_columns = taxi.arrived_at - taxi.start_at
taxi['wait_time'] = new_columns.astype('timedelta64[m]')

# %%
taxi['month'] = taxi['start_at'].dt.month

# %%
taxi.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type            start_at     start_lat     start_lon  \
# 0  executive       asap 2010-11-16 16:44:00  -12,13983536  -77,02355957
# 1  executive       asap 2010-06-01 00:34:00  -12,13874817  -76,99536133
# 2  executive       asap 2010-05-31 05:01:00  -12,12453079  -77,02780151
# 3  executive       asap 2010-06-01 00:29:00  -12,13885117  -76,99530029
# 4  executive   reserved 2010-09-11 23:55:00  -12,08995438  -76,92626953
#
#                end_at  ...  end_state driver_start_lat driver_start_lon  \
# 0 2010-11-16 17:29:00  ...   drop off     -12,10825481      -77,0272739
# 1 2010-06-01 00:37:00  ...  not found              NaN              NaN
# 2 2010-05-31 05:04:00  ...  not found              NaN              NaN
# 3 2010-06-01 00:32:00  ...  not found              NaN              NaN
# 4 2010-09-12 01:07:00  ...   drop off     -12,08311558      -76,9277072
#
#            arrived_at  source driver_score rider_score  wait_time  month  \
# 0 2010-11-16 17:02:00  iPhone          5.0         5.0       18.0     11
# 1                 NaT  iPhone          NaN         NaN        NaN      6
# 2                 NaT  iPhone          NaN         NaN        NaN      5
# 3                 NaT  iPhone          NaN         NaN        NaN      6
# 4 2010-09-11 23:50:00  iPhone          4.0         5.0       -5.0      9
#
#     weekday
# 0   Tuesday
# 1   Tuesday
# 2    Monday
# 3   Tuesday
# 4  Saturday
#
# [5 rows x 22 columns]

# %%
taxi['weekday'] = taxi['start_at'].dt.strftime('%A')

# %%
taxi.head(5)
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type            start_at     start_lat     start_lon  \
# 0  executive       asap 2010-11-16 16:44:00  -12,13983536  -77,02355957
# 1  executive       asap 2010-06-01 00:34:00  -12,13874817  -76,99536133
# 2  executive       asap 2010-05-31 05:01:00  -12,12453079  -77,02780151
# 3  executive       asap 2010-06-01 00:29:00  -12,13885117  -76,99530029
# 4  executive   reserved 2010-09-11 23:55:00  -12,08995438  -76,92626953
#
#                end_at  ...  end_state driver_start_lat driver_start_lon  \
# 0 2010-11-16 17:29:00  ...   drop off     -12,10825481      -77,0272739
# 1 2010-06-01 00:37:00  ...  not found              NaN              NaN
# 2 2010-05-31 05:04:00  ...  not found              NaN              NaN
# 3 2010-06-01 00:32:00  ...  not found              NaN              NaN
# 4 2010-09-12 01:07:00  ...   drop off     -12,08311558      -76,9277072
#
#            arrived_at  source driver_score rider_score  wait_time  month  \
# 0 2010-11-16 17:02:00  iPhone          5.0         5.0       18.0     11
# 1                 NaT  iPhone          NaN         NaN        NaN      6
# 2                 NaT  iPhone          NaN         NaN        NaN      5
# 3                 NaT  iPhone          NaN         NaN        NaN      6
# 4 2010-09-11 23:50:00  iPhone          4.0         5.0       -5.0      9
#
#     weekday
# 0   Tuesday
# 1   Tuesday
# 2    Monday
# 3   Tuesday
# 4  Saturday
#
# [5 rows x 22 columns]

# %%
taxi.query('month == [5, 6, 7]') \
    .groupby('month', as_index=False) \
    .agg({'journey_id': 'count'})
# Out:
#    month  journey_id
# 0      5        1585
# 1      6        1939
# 2      7        1516

# %%
ax = sns.countplot(x="month", data=taxi)

# %%
bx = sns.countplot(taxi['weekday'], order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 
                                           'Friday', 'Saturday', 'Sunday'])
sns.despine()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
taxi['end_state'].value_counts()
# Out:
# drop off         17417
# rider cancel      3976
# not found         1145
# driver cancel      292
# failure            249
# no show             20
# Name: end_state, dtype: int64

# %%
mau = (
    taxi.groupby('month') \
   .agg({'user_id': pd.Series.nunique})
)

# %%
# taxi_2 = taxi.groupby('month')['user_id'].nunique()     второй способ

# %%
mau
# Out:
#     month  user_id
# 0       1      102
# 1       2      111
# 2       3      163
# 3       4      254
# 4       5      275
# 5       6      309
# 6       7      318
# 7       8      377
# 8       9      416
# 9      10      437
# 10     11      504
# 11     12      569

# %%
plt.figure(figsize=(10, 6.5))
sns.lineplot(data=mau, markers = 'o-')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-c86d4cec76ac> in <module>
#       1 plt.figure(figsize=(10, 6.5))
# ----> 2 sns.lineplot(data=mau, markers = 'o-')
#
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     691     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     692     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
# --> 693     p.map_style(markers=markers, dashes=dashes, order=style_order)
#     694
#     695     if ax is None:
#
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_core.py in map(cls, plotter, *args, **kwargs)
#      51         # This method is assigned the __init__ docstring
#      52         method_name = "_{}_map".format(cls.__name__[:-7].lower())
# ---> 53         setattr(plotter, method_name, cls(plotter, *args, **kwargs))
#      54         return plotter
#      55
#
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_core.py in __init__(self, plotter, markers, dashes, order)
#     510
#     511             markers = self._map_attributes(
# --> 512                 markers, levels, unique_markers(len(levels)), "markers",
#     513             )
#     514             dashes = self._map_attributes(
#
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_core.py in _map_attributes(self, arg, levels, defaults, attr)
#     567             if len(levels) != len(arg):
#     568                 err = f"The `{attr}` argument has the wrong number of values"
# --> 569                 raise ValueError(err)
#     570             lookup_table = dict(zip(levels, arg))
#     571         elif arg:
#
# ValueError: The `markers` argument has the wrong number of values
