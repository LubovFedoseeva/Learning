# %%
import pandas as pd
import os

# %%
read_file = pd.read_excel (r'/home/jupyter-l.fedoseeva-12/Lesson_4/Dop_zadanie/inn.xls')
read_file.to_csv (r'/home/jupyter-l.fedoseeva-12/Lesson_4/Dop_zadanie/inn.csv', index = None, header=True)

# %%
inn = pd.read_csv('/home/jupyter-l.fedoseeva-12/Lesson_4/Dop_zadanie/inn.csv')

# %%
inn.shape
# Out:
# (2110, 20)

# %%
inn.dtypes
# Out:
# Unnamed: 0                 int64
# #                          int64
# name                      object
# reg_number                 int64
# address                   object
# head                      object
# head_job                  object
# head_inn                   int64
# phone                     object
# email                     object
# site                      object
# registration_date         object
# nalogoplatelschik_code    object
# oktmo_code                 int64
# okato_code                 int64
# registration_region       object
# okato_name                object
# field                     object
# capital,RUB                int64
# income,RUB                 int64
# dtype: object

# %%
read_file = pd.read_csv (r'/home/jupyter-l.fedoseeva-12/Lesson_4/Dop_zadanie/necessary_inn.txt', header=None)
read_file.columns = ['INN']
read_file.to_csv (r'/home/jupyter-l.fedoseeva-12/Lesson_4/Dop_zadanie/necessary_inn.csv', index = None, header=True)

# %%
neccesary_inn = pd.read_csv('/home/jupyter-l.fedoseeva-12/Lesson_4/Dop_zadanie/necessary_inn.csv')

# %%
neccesary_inn.dtypes
# Out:
# INN    int64
# dtype: object

# %%
neccesary_inn
# Out:
#               INN
# 0    394609645484
# 1    281578625230
# 2    923769811917
# 3    998694734508
# 4    271011690615
# ..            ...
# 110  664306216794
# 111  991951385204
# 112  129413497752
# 113  447901012904
# 114  634037614688
#
# [115 rows x 1 columns]

# %%
neccesary_inn = inn.head_inn.isin(neccesary_inn.INN)

# %%
inn.loc[neccesary_inn]
# Out:
#       Unnamed: 0     #                                name     reg_number  \
# 47            47    47                      Пермэнергосбыт  6417532956774
# 76            76    76              ЗАО «Кабанова Ковалев»  9343329412518
# 77            77    77                             Неофарм  3813743111150
# 85            85    85                         Арконик СМЗ  7465966885549
# 90            90    90                     Фармперспектива  6205521489390
# ...          ...   ...                                 ...            ...
# 2059        2059  2059    ЗАО «Кабанова, Титов и Бирюкова»  4405157155853
# 2074        2074  2074  ООО «Фомин, Симонова и Никифорова»  9213736030860
# 2089        2089  2089                  НПО «Зимин Иванов»  6791957421599
# 2106        2106  2106                           Юдина Лтд  5012825137426
# 2108        2108  2108                ООО «Хохлов Казаков»  9506828156265
#
#                                                 address  \
# ...

# %%
# второй вариант
selected_inn_data = inn[inn.head_inn.isin(neccesary_inn.INN)]; selected_inn_data
# Out:
#       Unnamed: 0     #                                name     reg_number  \
# 47            47    47                      Пермэнергосбыт  6417532956774
# 76            76    76              ЗАО «Кабанова Ковалев»  9343329412518
# 77            77    77                             Неофарм  3813743111150
# 85            85    85                         Арконик СМЗ  7465966885549
# 90            90    90                     Фармперспектива  6205521489390
# ...          ...   ...                                 ...            ...
# 2059        2059  2059    ЗАО «Кабанова, Титов и Бирюкова»  4405157155853
# 2074        2074  2074  ООО «Фомин, Симонова и Никифорова»  9213736030860
# 2089        2089  2089                  НПО «Зимин Иванов»  6791957421599
# 2106        2106  2106                           Юдина Лтд  5012825137426
# 2108        2108  2108                ООО «Хохлов Казаков»  9506828156265
#
#                                                 address  \
# ...

# %%
selected_inn_data['income,RUB'].sum()
# Out:
# 6104522627393

# %%
selected_inn_data.shape
# Out:
# (115, 20)
